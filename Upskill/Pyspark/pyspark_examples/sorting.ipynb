# %%
df = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/nanivasireddy99@gmail.com/emp.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.sort(df['ename'].desc()).show()
# Out:
# +-----+-----+--------+----------+-------+
# |EMPNO|ENAME|     JOB|  HIREDATE|Dept No|
# +-----+-----+--------+----------+-------+
# |   12|    L| ANALYST|21-09-1981|     40|
# |   11|    K| MANAGER|22-02-1981|     30|
# |   10|    J|SALESMAN|20-02-1981|     20|
# |    9|    I|   CLERK|17-12-1980|     10|
# |    8|    H| ANALYST|21-09-1981|     40|
# |    7|    G| MANAGER|22-02-1981|     30|
# |    6|    F|SALESMAN|20-02-1981|     20|
# |    5|    E|   CLERK|17-12-1980|     10|
# |    4|    D| ANALYST|21-09-1981|     40|
# |    3|    C| MANAGER|22-02-1981|     30|
# |    2|    B|SALESMAN|20-02-1981|     20|
# |    1|    A|   CLERK|17-12-1980|     10|
# +-----+-----+--------+----------+-------+

# %%
df.sort(df['ename'].desc()).show()
# Out:
# +-----+-----+--------+----------+-------+
# |EMPNO|ENAME|     JOB|  HIREDATE|Dept No|
# +-----+-----+--------+----------+-------+
# |   12|    L| ANALYST|21-09-1981|     40|
# |   11|    K| MANAGER|22-02-1981|     30|
# |   10|    J|SALESMAN|20-02-1981|     20|
# |    9|    I|   CLERK|17-12-1980|     10|
# |    8|    H| ANALYST|21-09-1981|     40|
# |    7|    G| MANAGER|22-02-1981|     30|
# |    6|    F|SALESMAN|20-02-1981|     20|
# |    5|    E|   CLERK|17-12-1980|     10|
# |    4|    D| ANALYST|21-09-1981|     40|
# |    3|    C| MANAGER|22-02-1981|     30|
# |    2|    B|SALESMAN|20-02-1981|     20|
# |    1|    A|   CLERK|17-12-1980|     10|
# +-----+-----+--------+----------+-------+

# %%
df.sort(df['Dept No'].asc()).show()
# Out:
# +-----+-----+--------+----------+-------+
# |EMPNO|ENAME|     JOB|  HIREDATE|Dept No|
# +-----+-----+--------+----------+-------+
# |    1|    A|   CLERK|17-12-1980|     10|
# |    5|    E|   CLERK|17-12-1980|     10|
# |    9|    I|   CLERK|17-12-1980|     10|
# |    2|    B|SALESMAN|20-02-1981|     20|
# |    6|    F|SALESMAN|20-02-1981|     20|
# |   10|    J|SALESMAN|20-02-1981|     20|
# |    3|    C| MANAGER|22-02-1981|     30|
# |    7|    G| MANAGER|22-02-1981|     30|
# |   11|    K| MANAGER|22-02-1981|     30|
# |    4|    D| ANALYST|21-09-1981|     40|
# |    8|    H| ANALYST|21-09-1981|     40|
# |   12|    L| ANALYST|21-09-1981|     40|
# +-----+-----+--------+----------+-------+

# %%
from pyspark.sql.functions import *
df.orderBy(col('Dept No')).show()
# Out:
# +-----+-----+--------+----------+-------+
# |EMPNO|ENAME|     JOB|  HIREDATE|Dept No|
# +-----+-----+--------+----------+-------+
# |    1|    A|   CLERK|17-12-1980|     10|
# |    5|    E|   CLERK|17-12-1980|     10|
# |    9|    I|   CLERK|17-12-1980|     10|
# |    2|    B|SALESMAN|20-02-1981|     20|
# |    6|    F|SALESMAN|20-02-1981|     20|
# |   10|    J|SALESMAN|20-02-1981|     20|
# |    3|    C| MANAGER|22-02-1981|     30|
# |    7|    G| MANAGER|22-02-1981|     30|
# |   11|    K| MANAGER|22-02-1981|     30|
# |    4|    D| ANALYST|21-09-1981|     40|
# |    8|    H| ANALYST|21-09-1981|     40|
# |   12|    L| ANALYST|21-09-1981|     40|
# +-----+-----+--------+----------+-------+

# %%
df.orderBy('Dept No').show()
# Out:
# +-----+-----+--------+----------+-------+
# |EMPNO|ENAME|     JOB|  HIREDATE|Dept No|
# +-----+-----+--------+----------+-------+
# |    1|    A|   CLERK|17-12-1980|     10|
# |    5|    E|   CLERK|17-12-1980|     10|
# |    9|    I|   CLERK|17-12-1980|     10|
# |    2|    B|SALESMAN|20-02-1981|     20|
# |    6|    F|SALESMAN|20-02-1981|     20|
# |   10|    J|SALESMAN|20-02-1981|     20|
# |    3|    C| MANAGER|22-02-1981|     30|
# |    7|    G| MANAGER|22-02-1981|     30|
# |   11|    K| MANAGER|22-02-1981|     30|
# |    4|    D| ANALYST|21-09-1981|     40|
# |    8|    H| ANALYST|21-09-1981|     40|
# |   12|    L| ANALYST|21-09-1981|     40|
# +-----+-----+--------+----------+-------+
